# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define file path
data_path = "data"
file_names = {
    "bitcoin": "bitcoin.csv",
    "gold": "gold.csv",
    "google_trends": "google_trends.csv",
    "sp500": "sp500.csv",
    "treasury_3m": "treasury_3m.csv",
    "treasury_10y": "treasury_10y.csv",
}

# Load datasets
data = {}
for key, file in file_names.items():
    file_path = os.path.join(data_path, file)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, parse_dates=["timestamp"])
        df.replace({'.': np.nan}, inplace=True)  # Replace non-numeric values with NaN
        for col in df.columns:
            if col != "timestamp":
                df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
        data[key] = df
    else:
        print(f"File not found: {file_path}")

# Merge datasets on timestamp
sp500 = data["sp500"]
sp500 = sp500.rename(columns={"Close": "sp500_close"})
all_data = sp500[["timestamp", "sp500_close"]]

for key, df in data.items():
    if key != "sp500" and df is not None:
        all_data = all_data.merge(df, on="timestamp", how="left")

# Convert timestamp back to datetime for sorting
all_data["timestamp"] = pd.to_datetime(all_data["timestamp"])
all_data.sort_values("timestamp", inplace=True)

# Fill missing values
all_data.fillna(method='ffill', inplace=True)

# **Scale features but keep a separate scaler for the target**
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Apply MinMax scaling to features only
feature_columns = [col for col in all_data.columns if col not in ["timestamp", "sp500_close"]]
all_data[feature_columns] = feature_scaler.fit_transform(all_data[feature_columns])

# Fit the scaler on S&P 500 closing price (target variable)
all_data["sp500_close_scaled"] = target_scaler.fit_transform(all_data[["sp500_close"]])

# Define prediction intervals
prediction_intervals = [7, 30, 180]
results = {}

for interval in prediction_intervals:
    print(f"Training LSTM model for {interval}-day prediction...")

    # Create target variable
    all_data[f"sp500_target_{interval}"] = all_data["sp500_close_scaled"].shift(-interval)

    # Drop rows with NaN values
    model_data = all_data.dropna(subset=[f"sp500_target_{interval}"])
    
    # Define features and target
    X = model_data[feature_columns].values
    y = model_data[f"sp500_target_{interval}"].values
    timestamps = model_data["timestamp"].values  # Store timestamps for plotting

    # Reshape input for LSTM (samples, time_steps, features)
    time_steps = 10  # Using past 10 days to predict the future
    X_lstm = []
    y_lstm = []
    timestamps_lstm = []

    for i in range(len(X) - time_steps):
        X_lstm.append(X[i : i + time_steps])
        y_lstm.append(y[i + time_steps])
        timestamps_lstm.append(timestamps[i + time_steps])  # Match timestamps with predictions

    X_lstm, y_lstm = np.array(X_lstm), np.array(y_lstm)
    timestamps_lstm = np.array(timestamps_lstm)

    # Train-test split
    X_train, X_test, y_train, y_test, timestamps_train, timestamps_test = train_test_split(
        X_lstm, y_lstm, timestamps_lstm, test_size=0.2, random_state=42)

    # Define LSTM model
    model = Sequential([
        LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.2),
        LSTM(50, return_sequences=False),
        Dropout(0.2),
        Dense(25),
        Dense(1)
    ])

    # Compile model
    model.compile(optimizer="adam", loss="mse")

    # Train model
    history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

    # Predict values
    y_pred = model.predict(X_test)

    # **FIX: Inverse transform only the target variable**
    y_test_original = target_scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
    y_pred_original = target_scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()

    # Prediction code
    df2 = pd.DataFrame({
        'Close': y_test_original,
        'Forecast': y_pred_original
    }, index=pd.to_datetime(timestamps_test))

    df2['PredictedReturn'] = df2['Forecast'] / df2['Close'] - 1
    df2.sort_index(inplace=True)

    initial_money = 100000.0
    cash_balance = 0.0
    shares = initial_money / df2['Close'].iloc[0]
    next_buy_date = None
    portfolio_vals = []

    for date, row in df2.iterrows():
        price = row['Close']
        pred_ret = row['PredictedReturn']

        if shares > 0 and pred_ret <= -0.01:
            cash_balance += shares * price
            shares = 0.0
            next_buy_date = date + pd.Timedelta(days=interval)
        elif shares == 0 and next_buy_date is not None and date >= next_buy_date and pred_ret >= 0.01:
            shares = cash_balance / price
            cash_balance = cash_balance % price
            next_buy_date = None

        portfolio_vals.append(cash_balance + shares * price)

    df2['StrategyValue'] = portfolio_vals
    df2['BuyHoldValue'] = initial_capital * (df2['Close'] / df2['Close'].iloc[0])

    strat_ret = df2['StrategyValue'].iloc[-1] / initial_capital - 1
    bh_ret = df2['BuyHoldValue'].iloc[-1]  / initial_capital - 1

    print(f"{interval}-day horizon:")
    print(f" Strategy return: {strat_ret*100:.2f}%")
    print(f" Buy & Hold return: {bh_ret*100:.2f}%")

    ax = df2[['StrategyValue','BuyHoldValue']].plot(
        figsize=(10,5), linewidth=2
    )
    ax.set_xlabel('Date')
    ax.set_ylabel('Portfolio Value ($USD)')
    ax.legend(['Strategy','Buy & Hold'])
    plt.tight_layout()
    plt.show()

    # End prediction code 

    # Evaluation metrics
    r2 = r2_score(y_test_original, y_pred_original)
    mae = mean_absolute_error(y_test_original, y_pred_original)
    mse = mean_squared_error(y_test_original, y_pred_original)
    rmse = np.sqrt(mse)

    results[interval] = {"R²": r2, "MAE": mae, "MSE": mse, "RMSE": rmse}

    print(f"Results for {interval}-day prediction:")
    print(f"R² score: {r2}")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")

    # Sort values by timestamp for plotting
    sorted_indices = np.argsort(timestamps_test)
    timestamps_sorted = timestamps_test[sorted_indices]
    y_test_sorted = y_test_original[sorted_indices]
    y_pred_sorted = y_pred_original[sorted_indices]

    # **FIX: Use actual prices instead of scaled values**
    plt.figure(figsize=(12, 6))
    plt.scatter(timestamps_sorted, y_pred_sorted, label="Predicted", color='red', marker='o')  # Predictions as dots
    plt.plot(timestamps_sorted, y_test_sorted, label="Actual", color='blue')  # Actual values as a line

    # Draw residual lines
    for i in range(len(timestamps_sorted)):
        plt.plot([timestamps_sorted[i], timestamps_sorted[i]], 
                 [y_pred_sorted[i], y_test_sorted[i]], 
                 color='gray', linestyle='dotted')

    plt.title(f"S&P 500 {interval}-day Prediction Residuals (LSTM)")
    plt.xlabel("Timestamp")
    plt.ylabel("S&P 500 Closing Price ($USD)")  # **FIXED Y-axis label**
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# Output results
print("Final results:", results)
# Out:
# Training LSTM model for 7-day prediction...
# Epoch 1/50
# C:\Users\carso\AppData\Local\Temp\ipykernel_21168\3423080645.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   all_data.fillna(method='ffill', inplace=True)
# C:\Users\carso\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0623 - val_loss: 0.0116
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143 - val_loss: 0.0108
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130 - val_loss: 0.0094
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150 - val_loss: 0.0094
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105 - val_loss: 0.0070
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095 - val_loss: 0.0081
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0089 - val_loss: 0.0085
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074 - val_loss: 0.0115
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - val_loss: 0.0061
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0071 - val_loss: 0.0048
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - val_loss: 0.0051
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057 - val_loss: 0.0044
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0074 - val_loss: 0.0039
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - val_loss: 0.0025
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step
# 7-day horizon:
#  Strategy return: 114.66%
#  Buy & Hold return: 22.56%
# Results for 7-day prediction:
# R² score: 0.9680103672436249
# Mean Absolute Error (MAE): 9.727083600281153
# Mean Squared Error (MSE): 164.51727712599873
# Root Mean Squared Error (RMSE): 12.826428853192096
# Training LSTM model for 30-day prediction...
# Epoch 1/50
# C:\Users\carso\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1152 - val_loss: 0.0160
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0205 - val_loss: 0.0063
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0132 - val_loss: 0.0059
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0102 - val_loss: 0.0079
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0104 - val_loss: 0.0055
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0103 - val_loss: 0.0049
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0106 - val_loss: 0.0050
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0092 - val_loss: 0.0061
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - val_loss: 0.0043
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - val_loss: 0.0050
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0052
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0084
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0089 - val_loss: 0.0033
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0035 - val_loss: 0.0030
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# 30-day horizon:
#  Strategy return: 70.22%
#  Buy & Hold return: 28.63%
# Results for 30-day prediction:
# R² score: 0.9634034422209901
# Mean Absolute Error (MAE): 11.45123322131587
# Mean Squared Error (MSE): 199.66290100442416
# Root Mean Squared Error (RMSE): 14.130212348171707
# Training LSTM model for 180-day prediction...
# Epoch 1/50
# C:\Users\carso\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0978 - val_loss: 0.0076
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123 - val_loss: 0.0040
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088 - val_loss: 0.0034
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - val_loss: 0.0037
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - val_loss: 0.0028
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058 - val_loss: 0.0029
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0043 - val_loss: 0.0030
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0017
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step
# 180-day horizon:
#  Strategy return: 18.24%
#  Buy & Hold return: 51.99%
# Results for 180-day prediction:
# R² score: 0.9799742526516796
# Mean Absolute Error (MAE): 7.7765410434133635
# Mean Squared Error (MSE): 111.47263979666766
# Root Mean Squared Error (RMSE): 10.55806041830921
# Final results: {7: {'R²': 0.9680103672436249, 'MAE': 9.727083600281153, 'MSE': 164.51727712599873, 'RMSE': 12.826428853192096}, 30: {'R²': 0.9634034422209901, 'MAE': 11.45123322131587, 'MSE': 199.66290100442416, 'RMSE': 14.130212348171707}, 180: {'R²': 0.9799742526516796, 'MAE': 7.7765410434133635, 'MSE': 111.47263979666766, 'RMSE': 10.55806041830921}}
